# %% [markdown]
# # Squared Image

# %%
from PIL import Image
from src.image.draw import resize_img
from src.image.merge import merge_text_to_image
from src.paths import LOCAL_PROCESSED_DATA_PATH

img = Image.open(str(LOCAL_PROCESSED_DATA_PATH / 'f98fc032ccfa0d923eaa8ed1459422e46336998a.JPEG'))
txt = "Two things are infinite: the universe and human stupidity; and I'm not sure about the universe."
merged = merge_text_to_image(img, txt)
resize_img(merged, (200,0))
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x244F2ED7520>

# %%
img = Image.open(str(LOCAL_PROCESSED_DATA_PATH / 'e74d9c86e497064ba00a38520cad86e4e4096295.JPEG'))
txt = "Two things are infinite: the universe and human stupidity; and I'm not sure about the universe."
merged = merge_text_to_image(img, txt)
resize_img(merged, (200,0))
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x244DF5AC670>

# %%
img = Image.open(str(LOCAL_PROCESSED_DATA_PATH / '98327b0750c163712064b7e39bd11bc5cae8da18.JPEG'))
txt = "Two things are infinite: the universe and human stupidity; and I'm not sure about the universe."
merged = merge_text_to_image(img, txt)
resize_img(merged, (200,0))
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x244F2ED7DF0>

# %% [markdown]
# # Narrow Cropped Images

# %%
img = Image.open(str(LOCAL_PROCESSED_DATA_PATH / '34f210b6c969f16a6ff9127ee6107f7f2d03eb6f.JPEG'))
txt = "Two things are infinite: the universe and human stupidity; and I'm not sure about the universe."
merged = merge_text_to_image(img, txt)
resize_img(merged, (200,0))
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x244F2ED7B80>
