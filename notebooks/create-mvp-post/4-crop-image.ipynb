# %%
from src.image.crop import crop
from src.image.extract import search

results = search(query='Einstein', type_='photos')
photo_urls = []

for photo in results.entries:
    photo_urls.append(photo.link_download)
    
url = photo_urls[0]
img = crop(url, export=True)
print(img.url, img.path)

img
# Out:
# https://unsplash.com/photos/zWQ7zsBr5WU/download c:\users\muril\documents\github\insta-post-generator\data\processed\537f46544f84899bf2835aab1dcd874ee0de0877.JPEG
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x1FB05945430>
