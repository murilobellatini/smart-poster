# %%
from src.image.crop import crop
from src.image.extract import search

results = search(query='Einstein', type_='photos')
photo_urls = []

for photo in results.entries:
    photo_urls.append(photo.link_download)
    
url = photo_urls[0]
img = crop(url, export=True, output_size=(850,1080))
print(img.url, img.path)

img
# Out:
# https://unsplash.com/photos/zWQ7zsBr5WU/download c:\users\muril\documents\github\insta-post-generator\data\processed\34f210b6c969f16a6ff9127ee6107f7f2d03eb6f.JPEG
# <PIL.Image.Image image mode=RGB size=850x1080 at 0x210065164F0>
