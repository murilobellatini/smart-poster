# %%
from src.helpers import select_closest
from src.image.draw import draw_text
txt = "Two things are infinite: the universe and human stupidity; and I'm not sure about the universe."
img = draw_text(txt, fontsize=25, fontcolor_hex='maroon', target_ar=0.6)
img
# Out:
# <PIL.Image.Image image mode=RGBA size=185x275 at 0x131F4924C10>
