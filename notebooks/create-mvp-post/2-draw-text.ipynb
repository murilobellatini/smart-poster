# %%
from src.image.draw import draw_text
draw_text("Two things are infinite:\nthe universe and human stupidity;\nand I'm not sure about the universe.",
          fontcolor_hex="maroon", fontsize=50,
          export=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=925x167 at 0x1CC89B93CD0>
