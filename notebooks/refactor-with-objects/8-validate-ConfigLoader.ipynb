# %%
from src.paths import LOCAL

# %%
root_path
# Out:
# WindowsPath('c:/users/muril/documents/github/insta-post-generator')

# %%
import os

SITE_ROOT = os.path.realpath(os.path.dirname(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b4f35a0c2b2c> in <module>
#       1 import os
#       2
# ----> 3 SITE_ROOT = os.path.realpath(os.path.dirname(__file__))
#
# NameError: name '__file__' is not defined

# %%
fdir = 'C:\Windows\Fonts'
os.listdir(fdir)
# Out:
# ['8514fix.fon',
#  '8514fixe.fon',
#  '8514fixg.fon',
#  '8514fixr.fon',
#  '8514fixt.fon',
#  '8514oem.fon',
#  '8514oeme.fon',
#  '8514oemg.fon',
#  '8514oemr.fon',
#  '8514oemt.fon',
#  '8514sys.fon',
#  '8514syse.fon',
#  '8514sysg.fon',
#  '8514sysr.fon',
#  '8514syst.fon',
#  '85775.fon',
#  '85855.fon',
#  '85f1255.fon',
#  '85f1256.fon',
#  '85f1257.fon',
#  '85f874.fon',
#  '85s1255.fon',
#  '85s1256.fon',
#  '85s1257.fon',
#  '85s874.fon',
#  'AGENCYB.TTF',
#  'AGENCYR.TTF',
#  'ALGER.TTF',
#  'ANTQUAB.TTF',
#  'ANTQUABI.TTF',
#  'ANTQUAI.TTF',
#  'app775.fon',
#  'app850.fon',
#  'app852.fon',
#  'app855.fon',
#  'app857.fon',
#  'app866.fon',
#  'app932.fon',
#  'app936.fon',
#  'app949.fon',
#  'app950.fon',
#  'arial.ttf',
#  'arialbd.ttf',
#  'arialbi.ttf',
#  'ariali.ttf',
#  'ARIALN.TTF',
#  'ARIALNB.TTF',
#  'ARIALNBI.TTF',
#  'ARIALNI.TTF',
#  'ARIALUNI.TTF',
#  'ariblk.ttf',
#  'ARLRDBD.TTF',
#  'bahnschrift.ttf',
#  'BASKVILL.TTF',
#  'BAUHS93.TTF',
# ...
