# %%
from src.image.text import TextDrawer
td = TextDrawer('Get to the Choppa!', font_color='white', target_ar=3, size=(0,300))
td.img
# Out:
# <PIL.Image.Image image mode=RGBA size=697x300 at 0x1550A3DF0D0>
