# %%
from src.image.text import TextDrawer
td = TextDrawer('Get to the Choppa!', font_color='yellow', target_ar=3)
td.draw_text()
# Out:
# <PIL.Image.Image image mode=RGBA size=372x165 at 0x20B1C23D6D0>
