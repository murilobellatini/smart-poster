# %%
from src.image.text import TextDrawer
td = TextDrawer('Get to the Choppa!', font_color='#2196F3', target_ar=3)
td.draw_text()
# Out:
# <PIL.Image.Image image mode=RGBA size=372x165 at 0x21EE81C1400>
