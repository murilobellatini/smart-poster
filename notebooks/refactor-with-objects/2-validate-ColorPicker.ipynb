# %%
from src.image.color import ColorPicker
from src.image import get_color_escape, RESET

url = 'https://image.api.playstation.com/vulcan/img/rnd/202010/2716/8pc2fi23ksuIvi0gEHO5EqV2.png'
cp = ColorPicker()
cp.load_url(img_url=url)
cp.scan_image()
cp.palette.extend([cp.contrast_color, cp.dominant_color])

for rgb in cp.palette:
    print(get_color_escape(*rgb) + str(cp.rgb2hex(rgb)) + str(rgb) + RESET)
    
cp.img
# Out:
# #3E8AB8(62, 138, 184)
# #DCC5C4(220, 197, 196)
# #681A1A(104, 26, 26)
# #A7BBCB(167, 187, 203)
# #815843(129, 88, 67)
# #77DAF6(119, 218, 246)
# [38;2;156.0;0.0;0.0m#9C0000(156.0, 0.0, 0.0)
# #3E8AB8(62, 138, 184)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x1796AADEB80>
