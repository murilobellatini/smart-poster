# %%
from src.paths import LOCAL_RAW_DATA_PATH
from src.image.detect import ComputerVision
cv = ComputerVision()
cv.load_path(LOCAL_RAW_DATA_PATH / 'einstein.JPEG')
cv._np2img(cv.draw_detection_bboxes(thresh=0.50))
# Out:
# 2021-04-22 11:36:42,288 [detect] [_setup_model] [INFO] Computer Vision setup with model: `OpenCV_dnn_DetectionModel`
#
# 2021-04-22 11:36:42,436 [detect] [detect_objects] [INFO] 1 object(s) detected. Minimum confidence level: 0.5
# <PIL.Image.Image image mode=RGB size=850x1080 at 0x1DABD122070>
