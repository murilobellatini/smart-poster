# %%
from src.content.produce import ContentProducer
cp = ContentProducer(
    themes=['batman', 'dream', 'dark', 'angel', 'thor', 'devil', 'god', 'music', 'rock'],
    posts_per_theme=10,
)
cp.produce_content()
# Out:
# 2021-04-24 18:05:21,339 [detect] [_setup_model] [INFO] Computer Vision setup with model: `OpenCV_dnn_DetectionModel`
#
# 2021-04-24 18:05:21,676 [detect] [detect_objects] [INFO] 1 object(s) detected. Minimum confidence level: 0.65
#
# 2021-04-24 18:05:28,221 [detect] [_setup_model] [INFO] Computer Vision setup with model: `OpenCV_dnn_DetectionModel`
#
# 2021-04-24 18:05:28,610 [detect] [detect_objects] [INFO] 0 object(s) detected. Minimum confidence level: 0.65
#
# 2021-04-24 18:05:28,611 [detect] [flip_if_necessary] [INFO] Image not flipped
#
# 2021-04-24 18:05:33,076 [detect] [_setup_model] [INFO] Computer Vision setup with model: `OpenCV_dnn_DetectionModel`
#
# 2021-04-24 18:05:33,218 [detect] [detect_objects] [INFO] 0 object(s) detected. Minimum confidence level: 0.65
#
# 2021-04-24 18:05:33,219 [detect] [flip_if_necessary] [INFO] Image not flipped
#
# 2021-04-24 18:05:39,078 [detect] [_setup_model] [INFO] Computer Vision setup with model: `OpenCV_dnn_DetectionModel`
#
# ...
